# %% [markdown]
# # Arithmetic Operators

# %%
add = 2 + 30
add
# Out:
# 32

# %%
add1 = 2
add1 += 3;

sub = 2
sub -= 1

mult = 2
mult *= 3

sub
# Out:
# 1

# %%
add1
# Out:
# 5

# %%
mult
# Out:
# 6

# %%
div1 = 4
div1 /= 3
div1
# Out:
# 1.3333333333333333

# %%
div1 = 4
div1 //= 3
div1
# Out:
# 1

# %%
div1 = 4
div1 %= 3
div1
# Out:
# 1

# %% [markdown]
# x = 10
# y = 5
# z = 3
# w = 2
#
# x += y * w - z // y
# x

# %%
g = 2
g *= 4 + 4
g
# Out:
# 16

# %% [markdown]
# ## bitwise not operator (~x)

# %%
x = ~5
x
# Out:
# -6

# %% [markdown]
# #### bitwise operator is inverts all the bits of the integer

# %% [markdown]
# here we take 5 bit number is 0000 0101
# For a positive integer, it computes the **two's complement of the number** (i.e., -(x + 1)).
# when we inverts bits
# 1111 1010 =
# if MSB is 1 then it is a negative number
# Add 1 to the the value 0000 0101    + 1
# result 0000 0110 which is 6 add negative sign
# ~x = -(x + 1)
# ~5 = -(5 + 1) = -6
# 5 in 8-bit binary: 0000 0101
# ~5 → flip all bits → 1111 1010
# if we take negative number
# -5
# ~(-5) = -(-5 + 1)
#  = -(-4)
#  = 4

# %% [markdown]
# ## bitwise operators

# %%
a = 5 # 0101
b = 3 # 0011
a&b
# Out:
# 1

# %% [markdown]
# 0101
# 0011
# **0001**

# %%
a|b
# Out:
# 7

# %% [markdown]
# 0101
# 0011
# **0111**

# %% [markdown]
# a ^ b

# %% [markdown]
# 0101
# 0011
# **0110**

# %%
a << 1  # binary:5= 0000 0101 shifting to the left by 1 bit
# Out:
# 10

# %% [markdown]
# 5 << 1
#  0000 0101
#  0000 1010
#  6

# %%
a >> 1
# Out:
# 2

# %% [markdown]
# 5 >> 1
#  0000 0101
#  0000 0010
# 2  here we shift to the right by 1 bit

# %% [markdown]
# x << 1
# multiple x by 2
# suppose x is 2
# x * 2
# 2 * 2 = 4
# 0000 0010
# after shifting
# 0000 0100
#
#
# x >> 1
# divide by 2
# x // 2
# x is 8
# 8//2 = 4
# 0000 1000
# after shifting
# 0000 0100
