# %% [markdown]
# # Heading

# %% [markdown]
# ## Small Heading

# %% [markdown]
# **bold Text**

# %% [markdown]
# *intalice*

# %% [markdown]
# ***Bold and Italic***

# %% [markdown]
# ~~Strikethrough Text~~

# %% [markdown]
# `inline code`

# %% [markdown]
# [Link Text](https://www.example.com)

# %% [markdown]
# > This is a blockquote.

# %% [raw]
# ![Alt Text](image_url.jpg)

# %% [markdown]
# * Item 1
# * Item 2
# * Item 3

# %% [markdown]
# 1. First Item
# 2. Second Item
# 3. Third Item

# %% [markdown]
# ####below is horizontal line

# %% [markdown]
# ---
